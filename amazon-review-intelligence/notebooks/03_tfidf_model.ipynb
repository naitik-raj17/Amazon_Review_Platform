# %% [markdown]
# # 03 — TF-IDF Sentiment Model
#
# Train Logistic Regression and Random Forest classifiers with TF-IDF features.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import json
from train_tfidf import train_tfidf_models
from utils import get_model_dir, load_env, setup_logging

load_env(PROJECT_ROOT / ".env")
logger = setup_logging("notebook_tfidf")

# %%
best_model, metrics, train_df, test_df = train_tfidf_models()
print(f"Best model: {metrics['best_model']}")

# %%
for name, result in metrics.items():
    if name == "best_model":
        continue
    print(f"\n{name}")
    print(f"  Accuracy:  {result['accuracy']:.4f}")
    print(f"  Precision: {result['precision']:.4f}")
    print(f"  Recall:    {result['recall']:.4f}")
    print(f"  F1 Score:  {result['f1_score']:.4f}")
    print(f"  Confusion Matrix: {result['confusion_matrix']}")

# %%
metrics_path = get_model_dir() / "tfidf_metrics.json"
with open(metrics_path) as f:
    saved_metrics = json.load(f)
saved_metrics["best_model"]
