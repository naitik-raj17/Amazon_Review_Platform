# %% [markdown]
# # 04 — DistilBERT Transformer Model
#
# Fine-tune `distilbert-base-uncased` for sentiment classification.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import json
from train_transformer import train_transformer_model
from predict import predict_sentiment
from utils import get_model_dir, load_env, setup_logging

load_env(PROJECT_ROOT / ".env")
logger = setup_logging("notebook_transformer")

# %%
output_dir, metrics = train_transformer_model(epochs=2)
print(f"Model saved to: {output_dir}")
print(f"F1 Score: {metrics['f1_score']:.4f}")

# %%
print(f"Accuracy:  {metrics['accuracy']:.4f}")
print(f"Precision: {metrics['precision']:.4f}")
print(f"Recall:    {metrics['recall']:.4f}")
print(f"Confusion Matrix: {metrics['confusion_matrix']}")

# %%
predict_sentiment("Product arrived late and packaging was damaged", model_type="transformer")

# %%
predict_sentiment("Amazing product quality and fast delivery!", model_type="transformer")
